# %%
import pandas as pd
df=pd.read_csv('pulwama_tweets.csv')
print(df)
# Out:
#       Unnamed: 0                            name                     location  \
# 0              0                           सिंधु                          NaN
# 1              1                  Anuj Choudhary             New Delhi, India
# 2              2              Hiten Panjankar 🇮🇳                        india
# 3              3                 Narendar Pandey                          NaN
# 4              4                         Teju 🇮🇳             Hyderabad, India
# 5              5           Muhammad Waseemakhter             Lahore, Pakistan
# 6              6                    Rajesh Singh                         भारत
# 7              7                    ਪੰਜਾਬ ਨਾਗਰਿਕ                        India
# 8              8                    News18Bangla               Kolkata, India
# 9              9              Hiten Panjankar 🇮🇳                        india
# 10            10                 Dipa Khandolkar                          NaN
# ...

# %%
df=df.drop(columns=['name','location','url','followers','datetime','description'])

# %%
print(df)
# Out:
#       Unnamed: 0                                               text
# 0              0  RT @M_pandit007: देश भक्ति के इस जज्बे को भी स...
# 1              1  Consequences Of Raised Custom Duty By India Up...
# 2              2  This is true face of @INCIndia  #PulwamaAttack...
# 3              3  पाकिस्तान के खिलाफ डिबेट में अगर कोई कहता है क...
# 4              4  पाकिस्तान के खिलाफ डिबेट में अगर कोई कहता है क...
# 5              5  اب بھارت کے کسان لال ٹماٹر پاکستان نہیں بھیجیں...
# 6              6  News channels should not invite politicians on...
# 7              7  Indian efforts to punish Pakistan economically...
# 8              8  #FakeNews #Pulwama #PulwamaAttack #PulwamaEnco...
# 9              9  Day by day dirty face of some people are comin...
# 10            10  यूॅ तो ज़माने भर में मिलते हैं कई आशिक ,\r\n\r...
# 11            11  This is true face of @INCIndia  #PulwamaAttack...
# 12            12  RT @Amitkalraj: बात का वक्त चला गया, ये नया भा...
# ...

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.to_csv('testingjusttweetspulwama.csv', index=False)
